# %%
import sys
from datetime import datetime
from pathlib import Path

# %%
from kafka import KafkaConsumer
from models import ride_deserializer

# %%
server = 'localhost:9092'
topic_name = 'rides'

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-console',
    value_deserializer=ride_deserializer
)

# %%
print(f"Listening to {topic_name}...")
count = 0
for message in consumer:
    ride = message.value
    pickup_dt = datetime.fromtimestamp(ride.tpep_pickup_datetime / 1000)
    print(f"Received: PU={ride.PULocationID}, DO={ride.DOLocationID}, "
          f"distance={ride.trip_distance}, amount=${ride.total_amount:.2f}, "
          f"pickup={pickup_dt}")
    count += 1
    if count >= 10:
        print(f"\n... received {count} messages so far (stopping after 10 for demo)")
        break

consumer.close()
# Out:
# Listening to rides...
# Received: PU=164, DO=114, distance=1.58, amount=$35.25, pickup=2025-11-01 00:31:44
# Received: PU=138, DO=74, distance=6.51, amount=$52.08, pickup=2025-11-01 00:47:05
# Received: PU=166, DO=262, distance=3.19, amount=$27.24, pickup=2025-11-01 00:13:36
# Received: PU=238, DO=238, distance=0.46, amount=$12.12, pickup=2025-11-01 00:25:26
# Received: PU=238, DO=166, distance=1.2, amount=$17.16, pickup=2025-11-01 00:40:05
# Received: PU=66, DO=246, distance=4.4, amount=$30.35, pickup=2025-11-01 00:12:04
# Received: PU=68, DO=239, distance=3.5, amount=$29.85, pickup=2025-11-01 00:53:50
# Received: PU=233, DO=161, distance=0.66, amount=$14.25, pickup=2025-11-01 00:17:28
# Received: PU=43, DO=239, distance=1.13, amount=$16.38, pickup=2025-11-01 00:27:41
# Received: PU=238, DO=166, distance=1.22, amount=$13.32, pickup=2025-11-01 00:42:29
#
# ... received 10 messages so far (stopping after 10 for demo)
